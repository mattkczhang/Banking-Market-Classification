# %% [markdown]
# ## MSCA 37014  Python for Analytics
# ### Group Members: Flora Huang, Jiawei Yu, Matt Zhang
# ### Assignment#1 Supervised Learning Regression Part 1 (125 points + 10 bonus points)
# ### Exploratory Data Analysis, Data Preprocessing, Simple and Multiple Linear Regression Model
# ### Due: 3/2/2022
# Please submit your assignment solutions in **PDF** or **HTML** file; **Submitted Jupyter Notebook will not be graded**
#
# ***
#
# In this assignment, please use Boston Housing Data (a set of features that describe a house in Boston) and the Linear Regression to train the machine learning model to predict the house price. You can find the Boston Housing Data in csv file in the updated Data folder I recently have shared. In this dataset, each row describes a boston town or suburb. There are 506 rows and 13 attributes (features) with a target column named as medv (price).
#
# ### Part 1 - Exploratory Data Analysis and Data Visualization (45 points + 10 bonus points)
#
# #### 1. Import Libraries and load the data into the Pandas data frame (5 points)
# #### 2. Review data dimension and data type for each feature in the dataset (5 points)
# #### 3. Identify the unique number of values of each feature in the dataset (5 points)
# #### 4. Check for missing values in the dataset (5 points)
# #### 5. Review the data summary statistics (5 points)
# #### 6. Create a correlation table with all the numeric features (5 points)
# #### 7. Plot a heatmap based on the correlation table from 6 (5 points)
# #### 8. Create some simple and quick plots with all the feature (hint: pairplot()) (5 points)
# #### 9. Create additional plots which could discover and support the key data findings for Part 1 (5 bonus points)
# #### 10. Make a Data Summary from Exploratory Data Analysis and Data Visualization for Part 1 (5 points + 5 bonus points)
# - 1) What are the features which are highly correlated to the target variable (MEDV)? (5 points)
# - 2) What additional data insights you think are valuable to share.(5 bonus points)
#
#
# ### Part 2 - Simple Linear Regression (only use one feature having the highest correlation coefficient with the target variable) (45 points)
#
# #### 1. Split the dataset into X, y, Training set, and Test set (only the highly correlated feature in X) (5 points)
# #### 2. Train the Simple Linear Regression model on the Training set (10 points)
# #### 3. Predict and visualize the Test set results (10 points)
# #### 4. Visualize the Training set results (5 points)
# #### 5. Make a single prediction (5 points)
# #### 6. Get the final linear regression equation (with values of the coefficients) (10 points)
#
#
# ### Part 3 - Multiple Linear Regression (35 points)
#
# #### 1. Split the dataset into X, y, Training set, and Test set (more than one feature in X) (5 points)
# #### 2. Train the Multiple Linear Regression model on the Training set (10 points)
# #### 3. Predict the Test set results (5 points)
# #### 4. Make a single prediction (5 points)
# #### 5. Get the final linear regression equation (with values of the coefficients) (10 points)

# %% [markdown]
# ### Boston Data Description
#
# - The medv variable is the **target variable**.
#
# - The Boston data frame has 506 rows and 13 columns.
#
# - This data frame contains the following columns:
#
# `crim`: per capita crime rate by town.
#
# `zn`: proportion of residential land zoned for lots over 25,000 sq.ft.
#
# `indus`: proportion of non-retail business acres per town.
#
# `chas`: Charles River dummy variable (= 1 if tract bounds river; 0 otherwise).
#
# `nox`: nitrogen oxides concentration (parts per 10 million).
#
# `rm`: average number of rooms per dwelling.
#
# `age`: proportion of owner-occupied units built prior to 1940.
#
# `dis`: weighted mean of distances to five Boston employment centres.
#
# `rad`: index of accessibility to radial highways.
#
# `tax`: full-value property-tax rate per \$10,000.
#
# `ptratio`: pupil-teacher ratio by town.
#
# `lstat`: lower status of the population (percent).
#
# `medv`: median value of owner-occupied homes in \$1000s.
#
#
# #### Source
#
# Harrison, D. and Rubinfeld, D.L. (1978) Hedonic prices and the demand for clean air. J. Environ. Economics and Management 5, 81–102.
#
# Belsley D.A., Kuh, E. and Welsch, R.E. (1980) Regression Diagnostics. Identifying Influential Data and Sources of Collinearity. New York: Wiley.
#
# ***
# ***

# %% [markdown]
# ## Part 1 - Exploratory Data Analysis and Data Visualization
#
# ### 1. Import Libraries and load the data into the pandas data frame

# %%
# Student's Answer: 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sbn


raw_data=pd.read_csv('/Users/cotwong/Documents/Uchi/37014Python/Data0129/BostonHousingData.csv')
raw_data.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#    LSTAT  MEDV
# 0   4.98  24.0
# 1   9.14  21.6
# 2   4.03  34.7
# 3   2.94  33.4
# 4   5.33  36.2

# %% [markdown]
# ### 2. Review data dimension and data type for each feature

# %%
# Student's Answer: 
print('Dimension:', raw_data.shape)
print('Data type:')
print(raw_data.dtypes)
# Out:
# Dimension: (506, 13)
# Data type:
# CRIM       float64
# ZN         float64
# INDUS      float64
# CHAS         int64
# NOX        float64
# RM         float64
# AGE        float64
# DIS        float64
# RAD          int64
# TAX          int64
# PTRATIO    float64
# LSTAT      float64
# MEDV       float64
# dtype: object

# %% [markdown]
# ### 3. Identify the unique number of values of each feature in the dataset

# %%
# Student's Answer:
for i in raw_data:
    print('The number of unqiue values of', i, 'are:', len(raw_data[i].unique()))
# Out:
# The number of unqiue values of CRIM are: 504
# The number of unqiue values of ZN are: 26
# The number of unqiue values of INDUS are: 76
# The number of unqiue values of CHAS are: 2
# The number of unqiue values of NOX are: 81
# The number of unqiue values of RM are: 446
# The number of unqiue values of AGE are: 356
# The number of unqiue values of DIS are: 412
# The number of unqiue values of RAD are: 9
# The number of unqiue values of TAX are: 66
# The number of unqiue values of PTRATIO are: 46
# The number of unqiue values of LSTAT are: 455
# The number of unqiue values of MEDV are: 229

# %% [markdown]
# ### 4. Check for missing values

# %%
# Student's Answer: 
print('Missing values by variables:')
print(raw_data.isna().sum())
# Out:
# Missing values by variables:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# LSTAT      0
# MEDV       0
# dtype: int64

# %% [markdown]
# ### 5. Review the data summary statistics

# %%
# Student's Answer:
raw_data.dropna().describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO       LSTAT  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534   12.653063
# ...

# %% [markdown]
# ### 6. Create a correlation table with all the numeric features

# %%
# Student's Answer: 
corr_table = raw_data.dropna().corr()
corr_table
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CRIM     1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247  0.352734
# ZN      -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991 -0.569537
# INDUS    0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676  0.644779
# CHAS    -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251  0.086518
# NOX      0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188  0.731470
# RM      -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000 -0.240265
# AGE      0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265  1.000000
# DIS     -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246 -0.747881
# RAD      0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847  0.456022
# TAX      0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048  0.506456
# PTRATIO  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355501  0.261515
# ...

# %% [markdown]
# ### 7. Plot a heatmap based on the correlation table from 6

# %%
# Student's Answer: 
corr_heatmap = sbn.heatmap(corr_table, annot=True)
corr_heatmap.set_title('Correlation Heatmap')
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap')

# %% [markdown]
# ### 8. Create some simple and quick plots with all the feature (hint: `pairplot()`)

# %%
# Student's Answer:
sbn.pairplot(raw_data.dropna())

# %% [markdown]
# ### 9. Create additional plots which could discover and support the key data findings for Part 1

# %%
# Student's Answer: 
hist_medv = sbn.histplot(raw_data['MEDV'])
hist_medv.set_title('Histagram of Median House Price')
hist_medv.set_xlabel('Median House Price')
# Out:
# Text(0.5, 0, 'Median House Price')

# %%
scatter_crim_medv_lstat = sbn.scatterplot(x = raw_data['CRIM'], y = raw_data['MEDV'], hue = raw_data['LSTAT'], size  = raw_data['LSTAT'])
scatter_crim_medv_lstat.set_title('Relationship Between Median House Price and Crime Rate')
scatter_crim_medv_lstat.set_xlabel('Crime Rate')
scatter_crim_medv_lstat.set_ylabel('Median House Price')
scatter_crim_medv_lstat.legend(title = 'Percentage of Lower \n Status Population')

# %%
box_chas_medv = sbn.boxplot(x = raw_data['CHAS'], y = raw_data['MEDV'])
box_chas_medv.set_title('Relationship Between Median House Price and House Location')
box_chas_medv.set_xlabel('0 means not near the river; 1 means near the river')
box_chas_medv.set_ylabel('Median House Price')
# Out:
# Text(0, 0.5, 'Median House Price')

# %%
scatter_dis_medv_rad = sbn.scatterplot(x = raw_data['DIS'], y = raw_data['MEDV'], hue = raw_data['RAD'], size  = raw_data['RAD'])
scatter_dis_medv_rad.set_title('Relationship Between Median House Price and Distance to Employment Centers')
scatter_dis_medv_rad.set_xlabel('Distance to Employment Center')
scatter_dis_medv_rad.set_ylabel('Median House Price')
scatter_dis_medv_rad.legend(title = 'Accessibility to \n Radial Highways')

# %% [markdown]
# ### 10. Make a Data Summary from Exploratory Data Analysis and Data Visualization
#
# - 1) What are the features which are highly correlated to the target variable (MEDV)? (5 points)
# - 2) What additional data insights you think are valuable to share.(5 bonus points)

# %%
# Student's Answer:
corr_table[np.logical_or(corr_table['MEDV'] > 0.5, corr_table['MEDV'] < -0.5)]['MEDV']
# Out:
# RM         0.695360
# PTRATIO   -0.507787
# LSTAT     -0.737663
# MEDV       1.000000
# Name: MEDV, dtype: float64

# %% [markdown]
# ## Part 2 - Simple Linear Regression (use the feature having the highest correlation coefficient with the target variable)
# ### 1. Split the dataset into X, y, Training set, and Test set (ony one feature in X)

# %%
# Student's Answer:
from sklearn.model_selection import train_test_split
X = raw_data[['LSTAT']]
y = raw_data['MEDV']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %% [markdown]
# ### 2. Train the Simple Linear Regression model on the Training set

# %%
# Student's Answer:
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ### 3. Predict and visualize the test set results

# %%
# Student's Answer:
y_pred = regressor.predict(X_test)

# %%
plt.scatter(X_test, y_test, color = 'red')
plt.plot(X_train, regressor.predict(X_train), color = 'blue')
plt.title('LSTAT VS MEDV (Test set)')
plt.xlabel('LSTAT')
plt.ylabel('MEDV')
plt.show()

# %% [markdown]
# ### 4. Visualize the training set results

# %%
# Student's Answer:
plt.scatter(X_train, y_train, color = 'red')
plt.plot(X_train, regressor.predict(X_train), color = 'blue')
plt.title('LSTAT VS MEDV (Training set)')
plt.xlabel('LSTAT')
plt.ylabel('MEDV')
plt.show()

# %% [markdown]
# ### 5. Make a single prediction

# %%
# Student's Answer:
print('The predicted median house price equal to', regressor.predict([[20]]), 'when lower status of the population equal to 20%')
# Out:
# The predicted median house price equal to [15.42] when lower status of the population equal to 20%
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %% [markdown]
# ### 6. Get the final linear regression equation (with values of the coefficients)

# %%
# Student's Answer:
print(' The final linear regressoin equation is: MEDV =', regressor.coef_, '* LSTAT +', regressor.intercept_)
# Out:
#  The final linear regressoin equation is: MEDV = [-0.95] * LSTAT + 34.32424077509831

# %% [markdown]
# ## Part 3 - Multiple Linear Regression
# ### 1. Split the dataset into X, y, Training set, and Test set (more than one feature in X)

# %%
# Student's Answer:)
X = raw_data.iloc[:, :-1].values
y = raw_data.iloc[:, -1].values
from sklearn.model_selection import train_test_split
X_train_ml, X_test_ml, y_train_ml, y_test_ml = train_test_split(X, y, test_size=0.3, random_state=101)

# %% [markdown]
# ### 2. Train the Multiple Linear Regression model on the Training set

# %%
# Student's Answer:
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train_ml, y_train_ml)
# Out:
# LinearRegression()

# %% [markdown]
# ### 3. Predict the test set results

# %%
# Student's Answer:
y_pred_ml = regressor.predict(X_test_ml)
np.set_printoptions(precision=2)
print(np.concatenate((y_pred_ml.reshape(len(y_pred_ml),1), y_test_ml.reshape(len(y_test_ml),1)),1))
# Out:
# [[40.04 50.  ]
#  [27.4  36.2 ]
#  [17.86 11.7 ]
#  [17.12 14.9 ]
#  [31.19 30.8 ]
#  [32.08 36.1 ]
#  [38.42 50.  ]
#  [ 8.74 13.2 ]
#  [33.63 41.3 ]
#  [ 6.61  8.5 ]
#  [30.48 23.5 ]
#  [13.17 13.3 ]
#  [16.88 20.2 ]
#  [17.37 18.6 ]
#  [25.11 18.5 ]
#  [20.42 27.9 ]
#  [ 8.08 10.4 ]
#  [33.19 28.5 ]
#  [28.69 28.4 ]
#  [24.59 23.1 ]
#  [11.73 12.8 ]
#  [20.05 21.7 ]
#  [22.59 11.9 ]
#  [24.41 29.6 ]
#  [33.94 37.3 ]
#  [18.37 19.9 ]
#  [32.6  29.  ]
#  [18.46 18.  ]
#  [27.45 50.  ]
#  [34.39 34.6 ]
#  [19.81 24.3 ]
#  [18.44 18.2 ]
#  [37.22 44.  ]
#  [45.05 50.  ]
#  [30.05 30.7 ]
#  [21.91 22.6 ]
#  [17.45 14.1 ]
#  [18.25 14.5 ]
#  [ 5.26  8.4 ]
#  [31.07 32.5 ]
#  [24.15 24.3 ]
#  [17.4  20.6 ]
#  [34.07 43.8 ]
#  [13.28 11.5 ]
#  [17.32 19.9 ]
#  [25.28 23.8 ]
#  [30.37 28.7 ]
#  [15.84 17.8 ]
#  [26.96 23.9 ]
#  [22.98 33.  ]
#  [32.1  31.5 ]
#  [37.16 21.9 ]
#  [23.35 17.4 ]
#  [19.37 15.  ]
#  [30.25 34.7 ]
#  [-0.86 13.8 ]
#  [20.38 20.4 ]
#  [16.64 19.5 ]
# ...

# %% [markdown]
# ### 4. Make a single prediction

# %%
# Student's Answer:
# assume CRIM=0.00723,ZN=15.0,INDUS=1.56,CHAS=0.0,NOX=0.521,RM=6.541,AGE=43.5,DIS=4.9820,RAD=1.0,
# TAX=245.0,PTRATIO=13.2 and LSTAT=3.21
print(regressor.predict([[0.00723,15.0,1.56,0.0,0.521,6.541,43.5,4.9820,1.0,245.0,13.2,3.21]]))
# Out:
# [32.26]

# %% [markdown]
# ### 5. Get the final linear regression equation (with values of the coefficients)

# %%
# Student's Answer:
print(regressor.coef_)
print(regressor.intercept_)
# Out:
# [-9.46e-02  5.05e-02  1.78e-02  3.91e+00 -1.80e+01  3.13e+00  1.38e-02
#  -1.41e+00  2.51e-01 -1.05e-02 -9.42e-01 -6.23e-01]
# 43.55010974438646

# %% [markdown]
# ## Great Job! :)

# %% [markdown]
# ***
#
# # Part 2
#
# ## Section 4 - Polynomial Linear Regression
#
# ### 1. Split the dataset into X, y, Training set, and Test set (exam and pick more than one feature or one strong feature in X based on the non-linear relationship with the target variable from data visualization) - similar as Section 3

# %%
# Student's Answer:
X = raw_data[['LSTAT']]
y = raw_data['MEDV']
X_train_ply, X_test_ply, y_train_ply, y_test_ply = train_test_split(X, y, test_size=0.3, random_state=101)

# %% [markdown]
# ### 2. Train the Polynomial Linear Regression model on the Training set

# %%
# Student's Answer:
from sklearn.preprocessing import PolynomialFeatures 
poly_reg = PolynomialFeatures(degree = 3) 
X_poly = poly_reg.fit_transform(X_train_ply) 
lin_reg_poly = LinearRegression()
lin_reg_poly.fit(X_poly, y_train_ply)
# Out:
# LinearRegression()

# %% [markdown]
# ### 3. Get the final linear regression equation (with values of the coefficients)

# %%
# Student's Answer:
print('Equation:\n', 'MEDV =',  lin_reg_poly.intercept_, '+', lin_reg_poly.coef_[1], 'LSTAT +',
     lin_reg_poly.coef_[2], 'LSTAT^2 +', lin_reg_poly.coef_[3], 'LSTAT^3')
# Out:
# Equation:
#  MEDV = 48.70116399642002 + -3.939116754954692 LSTAT + 0.1577399278419537 LSTAT^2 + -0.0022376820034613054 LSTAT^3

# %% [markdown]
# ## Section 5 - Decision Tree Regression

# %% [markdown]
# ### 1. Split the dataset into X, y, Training set, and Test set (more than one feature in X) - same as Section 3

# %%
# Student's Answer:
from sklearn.model_selection import train_test_split
X = raw_data[['RM','PTRATIO','LSTAT']]
y = raw_data['MEDV']
X_train_decision, X_test_decision, y_train_decision, y_test_decision = train_test_split(X, y, test_size=0.3, random_state=111)

# %% [markdown]
# ### 2. Train the Decision Tree Regression model on the Training set

# %%
# Student's Answer:
from sklearn.tree import DecisionTreeRegressor
regressor_tree=DecisionTreeRegressor(random_state=0)
regressor_tree.fit(X_train_decision,y_train_decision)
# Out:
# DecisionTreeRegressor(random_state=0)

# %% [markdown]
# ## Section 6 - Random Forest Regression
#
# ### 1. Split the dataset into X, y, Training set, and Test set (more than one feature in X) - same as Section 3

# %%
# Student's Answer:
X = raw_data[['RM','PTRATIO','LSTAT']]
y = raw_data['MEDV']
X_train_random, X_test_random, y_train_random, y_test_random = train_test_split(X, y, test_size=0.3, random_state=112)

# %% [markdown]
# ### 2. Train the Random Forest Regression model on the Training set

# %%
# Student's Answer:
from sklearn.ensemble import RandomForestRegressor
regressor_random=RandomForestRegressor(n_estimators=10,random_state=0)
regressor_random.fit(X_train_random,y_train_random)
# Out:
# RandomForestRegressor(n_estimators=10, random_state=0)

# %% [markdown]
# ## Section 7 - Calculate R Square for all 5 Regression models to Select the Best model
#
# - Any additional model evaluation metrics you think it would be good to use for all 5 Regression models (10 bonus points)

# %%
# Student's Answer:
from sklearn.metrics import r2_score, mean_squared_error
import math

# Single Var
sl_r2 = r2_score(y_test, y_pred)
sl_mse = mean_squared_error(y_test, y_pred)
sl_rmse = math.sqrt(sl_mse)
print('Simple Linear Regression R-squared = ', sl_r2)
print('Simple Linear Regression RMSE = ', sl_rmse)
# Out:
# Simple Linear Regression R-squared =  0.5123726572229699
# Simple Linear Regression RMSE =  6.957152209704265

# %%
# Multi-linear
ml_r2 = r2_score(y_test_ml, y_pred_ml)
ml_mse = mean_squared_error(y_test_ml, y_pred_ml)
ml_rmse = math.sqrt(ml_mse)
print('Multiple Linear Regression R-squared = ', ml_r2)
print('Multiple Linear Regression RMSE = ', ml_rmse)
# Out:
# Multiple Linear Regression R-squared =  0.7010730225422698
# Multiple Linear Regression RMSE =  5.447158789492387

# %%
# Polynomial:
X_poly = poly_reg.fit_transform(X_test_ply)
y_pred_ply = lin_reg_poly.predict(X_poly)
ply_r2 = r2_score(y_test_ply, y_pred_ply)
ply_mse = mean_squared_error(y_test_ply, y_pred_ply)
ply_rmse = math.sqrt(ply_mse)
print('Polynomial Regression R-squared = ', ply_r2)
print('Polynomial Regression RMSE = ', ply_rmse)
# Out:
# Polynomial Regression R-squared =  0.6432910066863898
# Polynomial Regression RMSE =  5.950377372509022

# %%
# Tree
y_pred_tree = regressor_random.predict(X_test_decision)
tree_r2 = r2_score(y_test_decision, y_pred_tree)
tree_mse = mean_squared_error(y_test_decision, y_pred_tree)
tree_rmse = math.sqrt(tree_mse)
print('Decision Tree R-squared = ', tree_r2)
print('Decision Tree RMSE = ', tree_rmse)
# Out:
# Decision Tree R-squared =  0.9177073403087874
# Decision Tree RMSE =  2.8568329907157866

# %%
# Random Forest
y_pred_rf = regressor_random.predict(X_test_random)
rf_r2 = r2_score(y_test_random, y_pred_rf)
rf_mse = mean_squared_error(y_test_random, y_pred_rf)
rf_rmse = math.sqrt(rf_mse)
print('Random Forest R-squared = ', rf_r2)
print('Random Forest RMSE = ', rf_rmse)
# Out:
# Random Forest R-squared =  0.8095007438101346
# Random Forest RMSE =  3.986002152269205
